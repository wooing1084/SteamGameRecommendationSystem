# %%
# import Required Libraries

import pandas as pd
import numpy as np
import dask.dataframe as dd

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# import data
users_df = dd.read_csv("../datasets/users.csv")
games_df = dd.read_csv("../datasets/games.csv")
rc_df = dd.read_csv("../datasets/recommendations.csv")

# %%
# merge recommendations and games df
rc_games_df = dd.merge(rc_df, games_df, on="app_id")
rc_games_df.head(5)
# Out:
#    app_id  helpful  funny        date  is_recommended  hours   user_id  \
# 0  975370        0      0  2022-12-12            True   36.3     49625
# 1  975370        0      0  2022-12-22            True   24.3  11722481
# 2  975370        3      0  2022-12-07            True  177.0  10786201
# 3  975370        5      0  2022-12-12            True  388.6   8460981
# 4  975370        0      0  2022-12-07            True   70.1  12438583
#
#    review_id           title date_release   win    mac  linux  \
# 0          0  Dwarf Fortress   2022-12-06  True  False  False
# 1        226  Dwarf Fortress   2022-12-06  True  False  False
# 2        316  Dwarf Fortress   2022-12-06  True  False  False
# 3       1182  Dwarf Fortress   2022-12-06  True  False  False
# 4       1346  Dwarf Fortress   2022-12-06  True  False  False
#
#                     rating  positive_ratio  user_reviews  price_final  \
# 0  Overwhelmingly Positive              95         19665         30.0
# ...

# %%
# Create user-item matrix
# 'user_id' 열을 카테고리로 변환
rc_games_df['user_id'] = rc_games_df['user_id'].astype('category')

# 'user_id' 열의 카테고리를 미리 알려진 상태로 변환
rc_games_df['user_id'] = rc_games_df['user_id'].cat.as_known()

user_item_matrix = rc_games_df.pivot_table(index="title", columns="user_id")
user_item_matrix_computed = user_item_matrix.compute()
user_item_matrix.head(5)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# d:\git\SteamGameRecommendationSystem\src\item_based.ipynb Cell 4 line 8
#       <a href='vscode-notebook-cell:/d%3A/git/SteamGameRecommendationSystem/src/item_based.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a> # 'user_id' 열의 카테고리를 미리 알려진 상태로 변환
#       <a href='vscode-notebook-cell:/d%3A/git/SteamGameRecommendationSystem/src/item_based.ipynb#W3sZmlsZQ%3D%3D?line=5'>6</a> rc_games_df['user_id'] = rc_games_df['user_id'].cat.as_known()
# ----> <a href='vscode-notebook-cell:/d%3A/git/SteamGameRecommendationSystem/src/item_based.ipynb#W3sZmlsZQ%3D%3D?line=7'>8</a> user_item_matrix = rc_games_df.pivot_table(index="title", columns="user_id")
#       <a href='vscode-notebook-cell:/d%3A/git/SteamGameRecommendationSystem/src/item_based.ipynb#W3sZmlsZQ%3D%3D?line=8'>9</a> user_item_matrix_computed = user_item_matrix.compute()
# ...
